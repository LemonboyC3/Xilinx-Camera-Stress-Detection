# %% [markdown]
# # Le Projiht

# %% [markdown]
# ### Intrnat

# %%
from pynq.lib import Wifi

port = Wifi()
port.reset()
# CityUHK_EE_GEF
# CityUHKEEWIFI
ssid = "CityUHK_EE_GEF"
pwd = "CityUHKEEWIFI"
port.connect(ssid, pwd)
print("Ensure connection")
# Out:
# Ensure connection

# %%
# !ping -c 3 google.com
# Out:
# PING google.com (142.250.198.46) 56(84) bytes of data.
# 64 bytes from nchkga-ap-in-f14.1e100.net (142.250.198.46): icmp_seq=1 ttl=113 time=13.4 ms
# 64 bytes from nchkga-ap-in-f14.1e100.net (142.250.198.46): icmp_seq=2 ttl=113 time=8.60 ms
# 64 bytes from nchkga-ap-in-f14.1e100.net (142.250.198.46): icmp_seq=3 ttl=113 time=16.7 ms
#
# --- google.com ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2002ms
# rtt min/avg/max/mdev = 8.604/12.914/16.732/3.336 ms

# %% [markdown]
# ### Libs

# %%
#!pip install --force-reinstall mediapipe
#!rm face_landmarker_v2_with_blendshapes.task
#!wget -O face_landmarker_v2_with_blendshapes.task -q https://storage.googleapis.com/mediapipe-models/face_landmarker/face_landmarker/float16/1/face_landmarker.task

# !pip uninstall numpy

# !pip install numpy==1.26.4


print("OK cool")
# Out:
# WARNING: Ignoring invalid distribution -axlib (/usr/local/share/pynq-venv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/usr/local/share/pynq-venv/lib/python3.10/site-packages)
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.2 MB)
# WARNING: Ignoring invalid distribution -axlib (/usr/local/share/pynq-venv/lib/python3.10/site-packages)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution -axlib (/usr/local/share/pynq-venv/lib/python3.10/site-packages)
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# WARNING: Ignoring invalid distribution -axlib (/usr/local/share/pynq-venv/lib/python3.10/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# OK cool

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import numpy as np
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import cv2

# %%
import matplotlib.pyplot as plt
import cv2

c = cv2.VideoCapture(0)
if not c.isOpened():
    print("Error: Could not access the webcam.")
ret, frame = c.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)
img = frame

# %%
import mediapipe as mp

BaseOptions = mp.tasks.BaseOptions
FaceLandmarker = mp.tasks.vision.FaceLandmarker
FaceLandmarkerOptions = mp.tasks.vision.FaceLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

options = FaceLandmarkerOptions(
    base_options=BaseOptions(model_asset_path="face_landmarker_v2_with_blendshapes.task"),
    running_mode=VisionRunningMode.IMAGE)


# Load the input image from an image file.
#mp_image = mp.Image.create_from_file('image.png')

# Load the input image from a numpy array.
mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame)

with FaceLandmarker.create_from_options(options) as landmarker:
    face_landmarker_result = landmarker.detect(mp_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 17>()
#       8 options = FaceLandmarkerOptions(
#       9     base_options=BaseOptions(model_asset_path="face_landmarker_v2_with_blendshapes.task"),
#      10     running_mode=VisionRunningMode.IMAGE)
#      13 # Load the input image from an image file.
#      14 #mp_image = mp.Image.create_from_file('image.png')
#      15
#      16 # Load the input image from a numpy array.
# ---> 17 mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame)
#      19 with FaceLandmarker.create_from_options(options) as landmarker:
#      20     face_landmarker_result = landmarker.detect(mp_image)
#
# TypeError: __init__(): incompatible constructor arguments. The following argument types are supported:
#     1. mediapipe.python._framework_bindings.image.Image(image_format: mediapipe::ImageFormat_Format, data: numpy.ndarray[numpy.uint8])
#     2. mediapipe.python._framework_bindings.image.Image(image_format: mediapipe::ImageFormat_Format, data: numpy.ndarray[numpy.uint16])
#     3. mediapipe.python._framework_bindings.image.Image(image_format: mediapipe::ImageFormat_Format, data: numpy.ndarray[numpy.float32])
#
# Invoked with: kwargs: image_format=<ImageFormat.SRGB: 1>, data=None

# %%
def draw_landmarks_on_image(rgb_image, detection_result):
  face_landmarks_list = detection_result.face_landmarks
  annotated_image = np.copy(rgb_image)

  # Loop through the detected faces to visualize.
  for idx in range(len(face_landmarks_list)):
    face_landmarks = face_landmarks_list[idx]

    # Draw the face landmarks.
    face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    face_landmarks_proto.landmark.extend([
      landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in face_landmarks
    ])

    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_tesselation_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp.solutions.drawing_styles
        .get_default_face_mesh_contours_style())
    solutions.drawing_utils.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks_proto,
        connections=mp.solutions.face_mesh.FACEMESH_IRISES,
          landmark_drawing_spec=None,
          connection_drawing_spec=mp.solutions.drawing_styles
          .get_default_face_mesh_iris_connections_style())

  return annotated_image
annotated_image = draw_landmarks_on_image(mp_image.numpy_view(), face_landmarker_result)
plt.imshow(annotated_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 38>()
#      29     solutions.drawing_utils.draw_landmarks(
#      30         image=annotated_image,
#      31         landmark_list=face_landmarks_proto,
#    (...)
#      34           connection_drawing_spec=mp.solutions.drawing_styles
#      35           .get_default_face_mesh_iris_connections_style())
#      37   return annotated_image
# ---> 38 annotated_image = draw_landmarks_on_image(mp_image.numpy_view(), face_landmarker_result)
#      39 plt.imshow(annotated_image)
#
# Input In [9], in draw_landmarks_on_image(rgb_image, detection_result)
#       7 face_landmarks = face_landmarks_list[idx]
#       9 # Draw the face landmarks.
# ---> 10 face_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
#      11 face_landmarks_proto.landmark.extend([
#      12   landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in face_landmarks
#      13 ])
#      15 solutions.drawing_utils.draw_landmarks(
#      16     image=annotated_image,
#      17     landmark_list=face_landmarks_proto,
#    (...)
#      20     connection_drawing_spec=mp.solutions.drawing_styles
#      21     .get_default_face_mesh_tesselation_style())
#
# NameError: name 'landmark_pb2' is not defined

# %%
import mediapipe as mp
mp_face_mesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False, max_num_faces=30, min_detection_confidence=0.5)
results = face_mesh.process(frame)
mark = frame
if results.multi_face_landmarks:
    for face_landmarks in results.multi_face_landmarks:
        mp_drawing.draw_landmarks(mark, face_landmarks, mp_face_mesh.FACEMESH_TESSELATION)
        print("Processed an image")
plt.imshow(mark)
# Out:
# W0000 00:00:1761913219.521233     939 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1761913219.601333     938 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Processed an image

# %%
# Try to use the model Indian man bestowed on us

from ultralytics import YOLO

import numpy as np


model = YOLO('/home/xilinx/jupyter_notebooks/last.pt')  # load a custom model

results = model(frame)  # predict on an image

names_dict = results[0].names

probs = results[0].probs.data.tolist()

print(names_dict)
print(probs)

print(names_dict[np.argmax(probs)])
# Out:
# 0: 224x224 stress 1.00, no stress 0.00, 201.6ms
# Speed: 24.5ms preprocess, 201.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
# {0: 'no stress', 1: 'stress'}
# [3.549312310724417e-08, 1.0]
# stress
